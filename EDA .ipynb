# %% [markdown]
# # Import required Labraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
data=pd.read_csv("Salary_Growth_DataSet.csv")
df=pd.DataFrame(data)
df
# Out:
#       Rating                      Company Name  \
# 0        3.8                            Sasken
# 1        4.5  Advanced Millennium Technologies
# 2        4.0                         Unacademy
# 3        3.8                SnapBizz Cloudtech
# 4        4.4            Appoids Tech Solutions
# ...      ...                               ...
# 5207     3.9                            qqqqqq
# 5208     3.9                       karan kumar
# 5209     3.9                          EduHazze
# 5210     3.9                     Rakesh Sharma
# 5211     5.0                      Pools of Fun
#
#                                               Job Title   Salary  \
# 0                                     Android Developer   400000
# 1                                     Android Developer   400000
# 2                                     Android Developer  1000000
# 3                                     Android Developer   300000
# 4                                     Android Developer   600000
# ...

# %% [markdown]
# # Data preparation

# %%
# Name of all columns in dataset 
df.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location', 'Employment Status', 'Job Roles'],
#       dtype='object')

# %%
# Finding missing values
df.isna().sum()
# Out:
# Rating               0
# Company Name         0
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Rating               0
# Company Name         0
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df
# Out:
#       Rating                      Company Name  \
# 0        3.8                            Sasken
# 1        4.5  Advanced Millennium Technologies
# 2        4.0                         Unacademy
# 3        3.8                SnapBizz Cloudtech
# 4        4.4            Appoids Tech Solutions
# ...      ...                               ...
# 5207     3.9                            qqqqqq
# 5208     3.9                       karan kumar
# 5209     3.9                          EduHazze
# 5210     3.9                     Rakesh Sharma
# 5211     5.0                      Pools of Fun
#
#                                               Job Title   Salary  \
# 0                                     Android Developer   400000
# 1                                     Android Developer   400000
# 2                                     Android Developer  1000000
# 3                                     Android Developer   300000
# 4                                     Android Developer   600000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5212 entries, 0 to 5211
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             5212 non-null   float64
#  1   Company Name       5212 non-null   object
#  2   Job Title          5212 non-null   object
#  3   Salary             5212 non-null   int64
#  4   Salaries Reported  5212 non-null   int64
#  5   Location           5212 non-null   object
#  6   Employment Status  5212 non-null   object
#  7   Job Roles          5212 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 325.9+ KB

# %%
df.dtypes
# Out:
# Rating               float64
# Company Name          object
# Job Title             object
# Salary                 int64
# Salaries Reported      int64
# Location              object
# Employment Status     object
# Job Roles             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5212 entries, 0 to 5211
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             5212 non-null   float64
#  1   Company Name       5212 non-null   object
#  2   Job Title          5212 non-null   object
#  3   Salary             5212 non-null   int64
#  4   Salaries Reported  5212 non-null   int64
#  5   Location           5212 non-null   object
#  6   Employment Status  5212 non-null   object
#  7   Job Roles          5212 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 325.9+ KB

# %%
df.describe()
# Out:
#             Rating        Salary  Salaries Reported
# count  5212.000000  5.212000e+03        5212.000000
# mean      3.918035  7.329787e+05           1.151381
# std       0.560842  7.075571e+05           0.611029
# min       1.000000  1.200000e+04           1.000000
# 25%       3.700000  3.000000e+05           1.000000
# 50%       4.000000  5.000000e+05           1.000000
# 75%       4.200000  1.000000e+06           1.000000
# max       5.000000  1.000000e+07          15.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
# I have to divide data in 2 part first 'df1' for EDA
# And second 'df2' for Machine learning

# %%
df1=df[['Company Name',
        'Job Title','Salary',
        'Salaries Reported','Location',
        'Employment Status','Job Roles']]
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#                           Company Name  \
# 0                               Sasken
# 1     Advanced Millennium Technologies
# 2                            Unacademy
# 3                   SnapBizz Cloudtech
# 4               Appoids Tech Solutions
# ...                                ...
# 5207                            qqqqqq
# 5208                       karan kumar
# 5209                          EduHazze
# 5210                     Rakesh Sharma
# 5211                      Pools of Fun
#
#                                               Job Title   Salary  \
# 0                                     Android Developer   400000
# 1                                     Android Developer   400000
# 2                                     Android Developer  1000000
# 3                                     Android Developer   300000
# 4                                     Android Developer   600000
# ...                                                 ...      ...
# ...

# %% [markdown]
# # Q1 Total number of employee job roles wise?

# %%
jobR=df1['Job Roles'].value_counts()
jobR
# Out:
# Android     1420
# Backend     1190
# Frontend    1090
# Database     864
# SDE          648
# Name: Job Roles, dtype: int64

# %%
jobR.plot.bar(title='Employee job roles graph')
# Out:
# <AxesSubplot:title={'center':'Employee job roles graph'}>

# %% [markdown]
# # Observation
#
# 1 Maximum employee hired in SDE company.
#  Minimum Employee hired in Mobile company

# %% [markdown]
# # Q2 Maximum and minimum salary of employee?

# %%
df1['Salary'].min()
# Out:
# 12000

# %%
df1['Salary'].max()
# Out:
# 10000000

# %% [markdown]
# # Q3 Employement Status of Employee?

# %%
ES=pd.DataFrame(df1['Employment Status'].value_counts())
ES
# Out:
#             Employment Status
# Full Time                4633
# Intern                    451
# Contractor                128

# %%
ES.plot.bar(color="Green")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q4 Employee count on the basis of location?

# %%
lc=pd.DataFrame(df1['Location'].value_counts())
lc
# Out:
#            Location
# Bangalore      2794
# New Delhi       814
# Mumbai          609
# Pune            484
# Chennai         399
# Hyderabad       112

# %%
lc.plot.bar(color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q5 Employee count on the basis of job title?

# %%
jt=pd.DataFrame(df1['Job Title'].value_counts())
jt
# Out:
#                                                  Job Title
# Android Developer                                     1063
# Front End Developer                                    681
# Backend Developer                                      534
# Software Development Engineer (SDE)                    177
# Software Development Engineer                          174
# ...                                                    ...
# oracle dba                                               1
# Senior Applications Database Administrator               1
# Ms SQL Server Database Administrator Contractor          1
# Database Administrator Developer                         1
# Senior Database Administrator (DBA)                      1
#
# [322 rows x 1 columns]

# %%
jt.plot.barh(color="Purple")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q6 Number of Employee job roles and status wise?

# %%
es=pd.DataFrame(df1[['Employment Status','Job Roles']][df1['Employment Status']=='Intern'].value_counts())
es
# Out:
#                                0
# Employment Status Job Roles
# Intern            Backend    193
#                   Android     95
#                   Frontend    92
#                   SDE         65
#                   Database     6

# %%
es.plot.barh(color='red',title="Intern Emp")
# Out:
# <AxesSubplot:title={'center':'Intern Emp'}, ylabel='Employment Status,Job Roles'>

# %%
es=pd.DataFrame(df1[['Employment Status','Job Roles']][df1['Employment Status']=='Full Time'].value_counts())
es
# Out:
#                                 0
# Employment Status Job Roles
# Full Time         Android    1289
#                   Backend     989
#                   Frontend    982
#                   Database    802
#                   SDE         571

# %%
es.plot.barh(color='red',title="Full Time Emp")
# Out:
# <AxesSubplot:title={'center':'Full Time Emp'}, ylabel='Employment Status,Job Roles'>

# %%
es=pd.DataFrame(df1[['Employment Status','Job Roles']][df1['Employment Status']=='Contractor'].value_counts())
es
# Out:
#                               0
# Employment Status Job Roles
# Contractor        Database   56
#                   Android    36
#                   Frontend   16
#                   SDE        12
#                   Backend     8

# %%
es.plot.barh(color='red',title="Contracter Emp")
# Out:
# <AxesSubplot:title={'center':'Contracter Emp'}, ylabel='Employment Status,Job Roles'>

# %% [markdown]
# # Q7 Employee whose salary is more than or equal to 1000000?

# %%
sa=pd.DataFrame(df1[['Company Name','Job Title','Salaries Reported','Location','Employment Status','Job Roles','Salary']]
                [df1['Salary']>=1000000])
sa.reset_index(drop=True,inplace=True)
sa
# Out:
#                          Company Name  \
# 0                           Unacademy
# 1                         J.P. Morgan
# 2                       powerplay app
# 3          Datamatics Global Services
# 4                    Ashwin Infotrron
# ...                               ...
# 1308                       Hello Soda
# 1309                Dad & Dave’s Turf
# 1310  Mr Singh's All Vegetarian Pizza
# 1311                   A.P. Nonweiler
# 1312      ABC Unified School District
#
#                                               Job Title  Salaries Reported  \
# 0                                     Android Developer                  3
# 1                                     Android Developer                  2
# 2                                     Android Developer                  2
# 3                                     Android Developer                  2
# 4                                     Android Developer                  1
# ...

# %% [markdown]
# # Q8 Number of employee whose salary is less than 50000?

# %%
sa=pd.DataFrame(df1[['Company Name','Job Title','Salaries Reported','Location','Employment Status','Job Roles','Salary']]
                [df1['Salary']<50000])
sa
# Out:
#                             Company Name  \
# 13                          Retail Pulse
# 514                          CodeCatalys
# 641                       Trippleatt.com
# 657                                 XYZA
# 769                    VVDN Technologies
# 837                             SheltOwn
# 914                             Decartem
# 950                Acmatics Technologies
# 1063  Transworld Compressor Technologies
# 2128       CityLink Technology Solutions
# 2150                 Innovative Tech Lab
# 2151                         StudyDuniya
# 2386                           TechoKids
# 2442                        qwertyqwerty
# 2444                            Bizzbuzz
# 3532                       First Student
# 3549                           Anonymous
# 3941                            Scholify
# 4026         Nasya Software Technologies
# 4048                               BTech
# 4056                           Numa Soft
# 4102                 WordPress Developer
# ...

# %% [markdown]
# # Q9  Location wise count of employees?

# %%
pd.DataFrame(df1['Location'].value_counts())
# Out:
#            Location
# Bangalore      2794
# New Delhi       814
# Mumbai          609
# Pune            484
# Chennai         399
# Hyderabad       112

# %% [markdown]
# # Applying Machine Learning

# %%
df2=df[['Rating','Salary','Salaries Reported']]
df2
# Out:
#       Rating   Salary  Salaries Reported
# 0        3.8   400000                  3
# 1        4.5   400000                  3
# 2        4.0  1000000                  3
# 3        3.8   300000                  3
# 4        4.4   600000                  3
# ...      ...      ...                ...
# 5207     3.9   100000                  1
# 5208     3.9   200000                  1
# 5209     3.9   120000                  1
# 5210     3.9   276000                  1
# 5211     5.0   800000                  1
#
# [5212 rows x 3 columns]

# %%
df2.dtypes
# Out:
# Rating               float64
# Salary                 int64
# Salaries Reported      int64
# dtype: object

# %%
df1['Employment Status'].value_counts()
# Out:
# Full Time     4633
# Intern         451
# Contractor     128
# Name: Employment Status, dtype: int64

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
x=df1.Salary.array.reshape(-1,1)
y=df2.Rating.array.reshape(-1,1)

# %%
y
# Out:
# <PandasArray>
# [
# [3.8],
# [4.5],
# [4.0],
# [3.8],
# [4.4],
# [4.2],
# [3.7],
# [3.1],
# [3.7],
# [3.6],
# [3.6],
# [3.9],
# [3.7],
# [4.8],
# [3.9],
# [3.9],
# [3.6],
# [3.7],
# [4.0],
# [3.6],
# [4.1],
# [4.2],
# [4.0],
# [4.4],
# [4.3],
# [3.6],
# [4.0],
# [4.9],
# [4.0],
# [3.7],
# [5.0],
# [4.2],
# [4.6],
# [3.9],
# [3.3],
# [5.0],
# [4.3],
# [2.9],
# [3.8],
# [4.0],
# [3.5],
# [3.0],
# [1.0],
# [2.9],
# [4.1],
# [3.7],
# [3.9],
# [3.8],
# [3.4],
# [4.5],
# [4.8],
# [3.7],
# [4.6],
# [2.8],
# [4.7],
# [4.1],
# [4.3],
# [4.1],
# [3.7],
# [4.3],
# [3.9],
# [4.6],
# [4.2],
# [5.0],
# [4.0],
# [4.5],
# [4.2],
# [3.9],
# [3.2],
# [4.0],
# [3.6],
# [3.3],
# [3.1],
# [2.8],
# [3.8],
# [3.7],
# [3.4],
# [3.0],
# [3.3],
# [3.1],
# [4.0],
# [3.7],
# [4.3],
# [4.5],
# [5.0],
# [5.0],
# [3.9],
# [4.8],
# [3.9],
# [3.4],
# [4.5],
# [4.1],
# [4.0],
# [3.8],
# [3.3],
# [4.8],
# [4.1],
# [3.7],
# [4.3],
# [4.0],
# [3.9],
# [4.1],
# [4.1],
# [4.0],
# [3.3],
# [4.4],
# [4.0],
# [4.0],
# ...

# %%
x
# Out:
# <PandasArray>
# [
# [400000],
# [400000],
# [1000000],
# [300000],
# [600000],
# [100000],
# [192000],
# [400000],
# [300000],
# [600000],
# [300000],
# [240000],
# [900000],
# [24000],
# [600000],
# [228000],
# [600000],
# [360000],
# [1000000],
# [500000],
# [408000],
# [300000],
# [800000],
# [228000],
# [100000],
# [500000],
# [200000],
# [500000],
# [228000],
# [708000],
# [396000],
# [700000],
# [500000],
# [500000],
# [900000],
# [200000],
# [228000],
# [400000],
# [600000],
# [400000],
# [500000],
# [216000],
# [216000],
# [300000],
# [540000],
# [400000],
# [500000],
# [400000],
# [100000],
# [252000],
# [700000],
# [100000],
# [200000],
# [156000],
# [348000],
# [600000],
# [300000],
# [864000],
# [120000],
# [400000],
# [168000],
# [400000],
# [96000],
# [1000000],
# [420000],
# [240000],
# [72000],
# [700000],
# [396000],
# [264000],
# [500000],
# [1000000],
# [672000],
# [276000],
# [800000],
# [200000],
# [492000],
# [600000],
# [300000],
# [300000],
# [432000],
# ...

# %%
# Spliting the dataset

from sklearn.model_selection import train_test_split

xtrain,ytrain,xtest,ytest=train_test_split(x,y,test_size=0.20)

# %%
xtrain.shape
# Out:
# (4169, 1)

# %%
ytrain.shape
# Out:
# (1043, 1)

# %%
xtest.shape
# Out:
# (4169, 1)

# %%
ytest.shape
# Out:
# (1043, 1)

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[1.96930574e-08]])

# %%
model.intercept_
# Out:
# array([3.90360071])

# %%
print(model.predict([[4.0]]))
# Out:
# [[3.90360079]]

# %%
model=LinearRegression()
model.fit(xtrain,xtest)
# Out:
# LinearRegression()

# %%
predict=model.predict(ytest)
predict
# Out:
# array([[3.90529954],
#        [3.90529954],
#        [3.90529955],
#        ...,
#        [3.90529955],
#        [3.90529953],
#        [3.90529953]])

# %%
# Overfitting and underfitting situation
model.score(xtest,xtrain)*100
# Out:
# -105.47761836166396

# %%
model.score(ytest,ytrain)*100
# Out:
# -116.71976124602014

# %%
# Regression evalution metrices:
#1 MAE
#2 MSE
#3 RMSE

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(ytest,predict))
# Out:
# 0.398420228788027

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(ytest,predict))
# Out:
# 0.31497061629688494

# %%
import math
print(math.sqrt(mean_squared_error(ytest,predict)))
# Out:
# 0.5612224303223143

# %%
sns.barplot(x='Salary',y='Rating',data=df)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Rating'>
